# %%
pip install git+https://github.com/openai/CLIP.git

# %%
pip install natsort

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import random
import torch.nn.functional as F

random.seed(42)

from src.graphs import (
    normalize_embeddings,
    calculate_distance, 
    build_knn_graph, 
    symmetrize_matrix, 
    compute_normalized_laplacian, 
    laplacian_difference
    )

from src.utils import ( 
    topk_eigenpairs, 
    ky_fan_k_norm, 
    xpec_discrepancy, 
    extract_mismatched_clusters
    )

from src.visualize import (
    plot_eigen_spectrum, 
    visualize_mismatched_clusters
    )

from src.datasets import Multi30k

# %%
# !python extract_embeddings.py --dataset multi30k --model t5 --batch_size 2048 --normalize
# !python extract_embeddings.py --dataset multi30k --model roberta --batch_size 2048 --normalize

# %%
model_1 = 'roberta'
model_2 = 'gpt'

# %%
# !python src/extract_features.py --feat_extractor $model_1 --caption_file /home/ssh_adnlp/reza/EXPECT/data/raw/multi30k/train.en
# !python src/extract_features.py --feat_extractor $model_2 --caption_file /home/ssh_adnlp/reza/EXPECT/data/raw/multi30k/train.en
# Out:
# Loaded 29000 texts.
# Extracting text features: 100%|███████████████| 454/454 [03:03<00:00,  2.48it/s]
# Saved features to ./gpt.npz

# %%
embed_1 = torch.from_numpy(np.load(f"{model_1}.npz")["features"])
embed_2 = torch.from_numpy(np.load(f"{model_2}.npz")["features"])

# %%
n_samples = 1000
random_indices = torch.randperm(embed_1.shape[0])[:n_samples]

emb1 = embed_1[random_indices]
emb2 = embed_2[random_indices]

# %%
def compute_laplacian(embeds, k=20, metric="cosine", concept_embedding=None):
    adj_matrix = build_knn_graph(embeds, k=k, metric=metric, concept_embedding=concept_embedding)

    adj_matrix = symmetrize_matrix(adj_matrix, mode="mean")
    L = compute_normalized_laplacian(adj_matrix)

    return adj_matrix, L

# %%
adj1, L1 = compute_laplacian(emb1)
adj2, L2 = compute_laplacian(emb2)

DeltaL = laplacian_difference(L1, L2)
print(DeltaL.shape)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1524.65it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1266.78it/s]
# torch.Size([1000, 1000])

# %%
#Temp visualisation 
fig, axs = plt.subplots(2,3, figsize=(20,10))
fig.delaxes(axs[0,2])

axs[0, 0].imshow(adj1.cpu().to_dense())
axs[0, 0].set_title("KNN_1")
axs[0, 1].imshow(adj2.cpu().to_dense())
axs[0, 1].set_title("KNN_2")

axs[1, 0].imshow(L1.cpu().to_dense())
axs[1, 0].set_title("L_1")
axs[1, 1].imshow(L2.cpu().to_dense())
axs[1, 1].set_title("L_2")
axs[1, 2].imshow(DeltaL.cpu().to_dense())
axs[1, 2].set_title("DeltaL")

for ax in axs.flatten():
    ax.axis("off")

plt.tight_layout()
plt.show()

# %%
def compute_eigens(matrix):
    n = matrix.shape[0]

    eigvals, eigvecs = torch.linalg.eigh(matrix)
    return eigvals, eigvecs
    
eigvals, eigvecs = compute_eigens(DeltaL)
plot_eigen_spectrum(eigvals)

# %%
import numpy as np
import umap
import matplotlib.pyplot as plt

def visualize(emb1, emb2, clusters):
    clustered_indices = []
    cluster_labels = []
    
    for cluster_id, cluster_indices in enumerate(clusters):
        if hasattr(cluster_indices, 'numpy'):
            indices = cluster_indices.cpu().numpy()
        else:
            indices = cluster_indices.cpu()
        
        clustered_indices.extend(indices)
        cluster_labels.extend([cluster_id] * len(indices))
    
    clustered_indices = np.array(clustered_indices)
    cluster_labels = np.array(cluster_labels)
    
    # Extract embeddings for both sets
    emb1_clustered = emb1[clustered_indices]
    emb2_clustered = emb2[clustered_indices]
    
    # UMAP
    reducer1 = umap.UMAP(n_components=2, random_state=42)
    embedding1_2d = reducer1.fit_transform(emb1_clustered)
    
    reducer2 = umap.UMAP(n_components=2, random_state=42)
    embedding2_2d = reducer2.fit_transform(emb2_clustered)
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))
    
    # Plot emb1
    scatter1 = ax1.scatter(embedding1_2d[:, 0], embedding1_2d[:, 1], c=cluster_labels, cmap='tab10', s=50, alpha=0.6)
    ax1.set_title('UMAP visualization of emb1 (clustered embeddings)', fontsize=14)
    ax1.set_xlabel('UMAP 1')
    ax1.set_ylabel('UMAP 2')
    plt.colorbar(scatter1, ax=ax1, label='Cluster ID')
    
    # Plot emb2
    scatter2 = ax2.scatter(embedding2_2d[:, 0], embedding2_2d[:, 1], c=cluster_labels, cmap='tab10', s=50, alpha=0.6)
    ax2.set_title('UMAP visualization of emb2 (clustered embeddings)', fontsize=14)
    ax2.set_xlabel('UMAP 1')
    ax2.set_ylabel('UMAP 2')
    plt.colorbar(scatter2, ax=ax2, label='Cluster ID')
    
    plt.tight_layout()
    plt.show()

# %%
discrepancy = xpec_discrepancy(DeltaL, k=2, mode = "kyfan")
discrepancy
# Out:
# tensor(1.4194, device='cuda:0')

# %%
# Mismatched clusters
n_modes = 5
eigvals, eigvecs = topk_eigenpairs(DeltaL, k=n_modes)
# clusters = extract_mismatched_clusters(eigvecs, threshold=DeltaL)
clusters = extract_mismatched_clusters(eigvecs, top_n=10)
print(f"Found {len(clusters)} mismatched clusters")

visualize(emb1, emb2, clusters)
# Out:
# Found 5 mismatched clusters
# /home/ssh_adnlp/miniconda3/envs/thinker/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/ssh_adnlp/miniconda3/envs/thinker/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
emb1.shape
# Out:
# torch.Size([1000, 768])

# %%
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
import pandas as pd
import numpy as np
from src.datasets import Multi30k


embeds = emb1
indices = range(0,emb1.shape[0])

embeds_np = embeds.float().numpy()

print(f"{'='*20} Cluster Analysis {'='*20}")
dataset = Multi30k(split="train")
# df = pd.DataFrame({'Index': indices, 'Cluster': clusters})

for c in range(n_modes):
    print(f"\n🚀 Cluster {c}:")
    cluster_indices = clusters[c]
    
    # Print up to 3 samples per cluster
    for i, idx in enumerate(cluster_indices):
        item = dataset[idx.item()]
        # Try to get English text, fallback to generic 'text' field
        text = item.get('text_en', item.get('text', '[No text found]'))
        print(f"  {i+1}. {text}")
# Out:
# ==================== Cluster Analysis ====================
# Loading compiled data for split: train
#
# 🚀 Cluster 0:
#   1. Numerous people sitting on the ground near a straw hut.
#   2. A man is carrying a trash barrel past a statue of an angel.
#   3. A elderly father and his grown son are preparing for a camping trip in the wild.
#   4. A white dog jumping to catch a red ball.
#   5. The regional park police helicopter is preparing to land.
#   6. A young man looks at a book on the ground in a wooded area.
#   7. People waiting in line for their favorite beverage.
#   8. A black dog and a white dog are standing on snow.
#   9. A girl removes her eye makeup with an ear swab.
#   10. A guy in a yellow shirt and light brown slacks is playing golf while the crowd watch.
#
# 🚀 Cluster 1:
#   1. A wet black dog is carrying a green toy through the grass.
#   2. A group of worshipers hold their services in a public park.
#   3. A man wearing a yellow shirt standing in the middle of two beds that a boy is jumping on in the background
#   4. Two men squat to light candles at night.
#   5. A man is standing in front of a skyscraper
#   6. There are three swimmers from the same team getting ready to compete.
#   7. Numerous people sitting on the ground near a straw hut.
#   8. A woman is jogging on a sidewalk next to an elevated grassy platform.
#   9. A white dog is about to catch a yellow dog toy.
#   10. Five construction workers dig a hole to plant a tree.
#
# 🚀 Cluster 2:
#   1. Several children sit on a carnival ride in front of the face of a clown and several fake balloons.
#   2. A farmer walks his pet pig down the dirt road.
#   3. A white dog jumping to catch a red ball.
#   4. A girl in a green shirt jumps in the air.
#   5. A little boy and his bike sit outside the Kuthhoop Hotel.
#   6. Asian man and blond woman holding hands outdoors, man in background watches.
#   7. The woman with the hat is selling some fruits and root crops.
#   8. A lady in a red and black striped shirt is sitting on a retaining wall.
#   9. A small girl playing, on the sidewalk, with a stick.
#   10. People walk around and mingle in a large open space with a dog.
#
# 🚀 Cluster 3:
#   1. Two men squat to light candles at night.
#   2. A woman is jogging on a sidewalk next to an elevated grassy platform.
#   3. A man wearing a yellow shirt standing in the middle of two beds that a boy is jumping on in the background
#   4. Five construction workers dig a hole to plant a tree.
#   5. People waiting to cross the street in front of a pharmacy with lit up sign.
#   6. Five people are sitting in a circle with instruments.
#   7. A large structure has broken and is laying in a roadway.
#   8. A group of worshipers hold their services in a public park.
#   9. A wet black dog is carrying a green toy through the grass.
#   10. A man with swords battling a female with a spear.
#
# 🚀 Cluster 4:
#   1. A girl removes her eye makeup with an ear swab.
#   2. A man is sitting at an outside bar near many soda and beer cans.
#   3. Two men and two women are preparing a large meal in the kitchen.
#   4. A woman talks animatedly to her companion next to a body of water.
#   5. A young man looks at a book on the ground in a wooded area.
#   6. Three people enter a building with a handwritten sign that says "Welcome Bikers."
#   7. Two women, sitting at a table, with a green straw inside of a drink.
#   8. A little boy playing in the water.
#   9. A woman in Muslim attire is walking with a young boy down the street.
#   10. A woman squatting in the grass is smiling at a little boy, as he smiles and raises his hands in the air.

# %% [markdown]
# ## Concept-Conditioned Analysis
# ### An edge is strong only if two nodes are close together and the neighbor is relevant to the target concept.

# %%
with open('concept.txt', 'w') as f: 
    f.write('Dog')

# %%
# !python src/extract_features.py --feat_extractor $model_1 --caption_file /home/ssh_adnlp/reza/EXPECT/concept.txt --output "{model_1}_concept.npz"
# !python src/extract_features.py --feat_extractor $model_2 --caption_file /home/ssh_adnlp/reza/EXPECT/concept.txt --output "{model_2}_concept.npz"
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Loaded 1 texts.
# Extracting text features: 100%|███████████████████| 1/1 [00:00<00:00,  3.16it/s]
# Saved features to roberta_concept.npz
# Loaded 1 texts.
# Extracting text features: 100%|███████████████████| 1/1 [00:00<00:00,  2.97it/s]
# Saved features to gpt_concept.npz

# %%
concept_emb1 = torch.from_numpy(np.load(f"{model_1}_concept.npz")['features'])
concept_emb2 = torch.from_numpy(np.load(f"{model_2}_concept.npz")['features'])

adj1, L1 = compute_laplacian(emb1, concept_embedding=concept_emb1)
adj2, L2 = compute_laplacian(emb2, concept_embedding=concept_emb2)

DeltaL = laplacian_difference(L1, L2)
print(DeltaL.shape)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1708.47it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1059.44it/s]
# torch.Size([1000, 1000])

# %%
#Temp visualisation 
fig, axs = plt.subplots(2,3, figsize=(20,10))
fig.delaxes(axs[0,2])

axs[0, 0].imshow(adj1.cpu().to_dense())
axs[0, 0].set_title("KNN_1")
axs[0, 1].imshow(adj2.cpu().to_dense())
axs[0, 1].set_title("KNN_2")

axs[1, 0].imshow(L1.cpu().to_dense())
axs[1, 0].set_title("L_1")
axs[1, 1].imshow(L2.cpu().to_dense())
axs[1, 1].set_title("L_2")
axs[1, 2].imshow(DeltaL.cpu().to_dense())
axs[1, 2].set_title("DeltaL")

for ax in axs.flatten():
    ax.axis("off")

plt.tight_layout()
plt.show()

# %%
# Mismatched clusters
n_modes = 2
eigvals, eigvecs = topk_eigenpairs(DeltaL, k=n_modes)
# clusters = extract_mismatched_clusters(eigvecs, threshold=DeltaL)
clusters = extract_mismatched_clusters(eigvecs, top_n=20)
print(f"Found {len(clusters)} mismatched clusters")

visualize(emb1, emb2, clusters)
# Out:
# Found 2 mismatched clusters
# /home/ssh_adnlp/miniconda3/envs/thinker/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/ssh_adnlp/miniconda3/envs/thinker/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
import pandas as pd
import numpy as np
from src.datasets import Multi30k


embeds = emb1
indices = range(0,emb1.shape[0])

embeds_np = embeds.float().numpy()

print(f"{'='*20} Cluster Analysis {'='*20}")
dataset = Multi30k(split="train")
# df = pd.DataFrame({'Index': indices, 'Cluster': clusters})

for c in range(n_modes):
    print(f"\n🚀 Cluster {c}:")
    cluster_indices = clusters[c]
    
    # Print up to 3 samples per cluster
    for i, idx in enumerate(cluster_indices):
        item = dataset[idx.item()]
        # Try to get English text, fallback to generic 'text' field
        text = item.get('text_en', item.get('text', '[No text found]'))
        print(f"  {i+1}. {text}")
# Out:
# ==================== Cluster Analysis ====================
# Loading compiled data for split: train
#
# 🚀 Cluster 0:
#   1. A elderly father and his grown son are preparing for a camping trip in the wild.
#   2. Numerous people sitting on the ground near a straw hut.
#   3. A group of children in brown outfits are performing.
#   4. A white dog jumping to catch a red ball.
#   5. A girl removes her eye makeup with an ear swab.
#   6. A young man looks at a book on the ground in a wooded area.
#   7. People waiting in line for their favorite beverage.
#   8. The regional park police helicopter is preparing to land.
#   9. A man is carrying a trash barrel past a statue of an angel.
#   10. A guy in a yellow shirt and light brown slacks is playing golf while the crowd watch.
#   11. Two men are working on train tracks.
#   12. A black dog and a white dog are standing on snow.
#   13. A heavyset couple interact outside a striped cabana on a beach located near a pier.
#   14. Men wearing hard hats and safety vests are working.
#   15. Couple, man and woman, with little girl all of them dressed in wedding apparel while standing along shoreline.
#   16. A man with a beard and a hat is begging for money from people.
#   17. A man is sitting at an outside bar near many soda and beer cans.
#   18. A man with two dogs on a beach
#   19. A little girl with a tiara eating in someones lap.
#   20. A young boy with swimming goggles, jumping into a swimming pool.
#
# 🚀 Cluster 1:
#   1. A wet black dog is carrying a green toy through the grass.
#   2. A group of worshipers hold their services in a public park.
#   3. There are three swimmers from the same team getting ready to compete.
#   4. A man wearing a yellow shirt standing in the middle of two beds that a boy is jumping on in the background
#   5. A man is standing in front of a skyscraper
#   6. Five people are sitting in a circle with instruments.
#   7. Two men squat to light candles at night.
#   8. A white dog is about to catch a yellow dog toy.
#   9. A woman is jogging on a sidewalk next to an elevated grassy platform.
#   10. Two men in a room looking at a computer screen.
#   11. A woman with dirty blond-hair and glasses is cutting something.
#   12. People waiting to cross the street in front of a pharmacy with lit up sign.
#   13. Five construction workers dig a hole to plant a tree.
#   14. Numerous people sitting on the ground near a straw hut.
#   15. A tan colored dog is jumping into an outdoor pool.
#   16. A gentleman in traditional garb weaving a blanket in a field.
#   17. Two young male hikers using a map and compass to find their direction in the woods.
#   18. A large structure has broken and is laying in a roadway.
#   19. A teenage boy is jumping on an inflatable slide.
#   20. Two girls crouch in front of some bushes and talk on their phones.
